# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=np.random.random((12,12))
plt.imshow(data,cmap='winter')

# %%
ax=sns.heatmap(data,linewidth='0.7',cmap='winter')

# %%
plt.pcolormesh(data,cmap='winter')
