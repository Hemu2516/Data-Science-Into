# %%
import pandas as pd
import numpy as np
df=pd.read_csv("5.csv")
df
# Out:
#           ID                                       Name Sex   Age  Height  \
# 0         67    Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0
# 1        411                             Gezahgne Abera   M  22.0   166.0
# 2        428                          Elvan Abeylegesse   F  25.0   159.0
# 3        846       Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0
# 4        846       Valerie Kasanita Adams-Vili (-Price)   F  27.0   193.0
# ...      ...                                        ...  ..   ...     ...
# 1108  135095                            Szymon Zikowski   M  24.0   192.0
# 1109  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  35.0   183.0
# 1110  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  39.0   183.0
# 1111  135563                  Olesya Nikolayevna Zykina   F  19.0   171.0
# 1112  135563                  Olesya Nikolayevna Zykina   F  23.0   171.0
#
#       Weight         Team  NOC        Games  Year  Season     City      Sport  \
# ...

# %%
df.isnull().sum()
# Out:
# ID         0
# Name       0
# Sex        0
# Age        4
# Height     6
# Weight    10
# Team       0
# NOC        0
# Games      0
# Year       0
# Season     0
# City       0
# Sport      0
# Event      0
# Medal      0
# dtype: int64

# %%
df.interpolate(inplace=True)

# %%
df.isnull().sum()
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
df.describe()
# Out:
#                   ID          Age       Height       Weight         Year
# count    1113.000000  1113.000000  1113.000000  1113.000000  1113.000000
# mean    66293.287511    26.164870   176.971249    70.739443  2006.080863
# std     38961.671305     4.026106    10.246713    17.866862     6.833893
# min        67.000000    17.000000   150.000000    40.000000  1996.000000
# 25%     32382.000000    23.000000   170.000000    59.000000  2000.000000
# 50%     64347.000000    26.000000   176.000000    67.000000  2008.000000
# 75%    100516.000000    29.000000   185.000000    80.000000  2012.000000
# max    135563.000000    40.000000   207.000000   154.000000  2016.000000

# %%
import matplotlib.pyplot as plt

# %%
age = df['Age'] 
plt.boxplot(age,vert=False,meanline = True ,showmeans = True)
plt.show()

# %%
values = df['Height']
plt.boxplot(values,vert=False,meanline = True ,showmeans = True)
plt.show()

# %%
values = df['Weight']
plt.boxplot(values,vert=False,meanline = True ,showmeans = True)
plt.show()

# %%
df.nunique()
# Out:
# ID        811
# Name      811
# Sex         2
# Age        25
# Height     55
# Weight     81
# Team       78
# NOC        78
# Games       6
# Year        6
# Season      1
# City        6
# Sport       1
# Event      48
# Medal       3
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df['Year'].unique()
# Out:
# array([2008, 2000, 2012, 2016, 1996, 2004], dtype=int64)

# %%
import matplotlib.pyplot as plt
plt.hist(df['Medal'],edgecolor='black',color='blue')
plt.show()

# %%
# Linear Regression between Height and weight

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score

y = df['Weight']
x = df['Height']

plt.plot(x,y,'ro')
b1,b0 = np.polyfit(x,y,deg=1)
print('y hat = ',b0,'+',b1,'x')

plt.plot(x,y,'go')
b1,b0 = np.polyfit(x,y,deg=1)
yp = b0 + b1*x
plt.plot(x,yp)
plt.show()
# Coefficient of determination
print(r2_score(y,yp))
plt.scatter(y,x,color = 'goldenrod')
b1,b0 = np.polyfit(y,x,1)
y_p = b0 + b1*np.array(y)
plt.plot(y, y_p)
plt.show()
residuals = np.array(df.Height - y_p)
plt.scatter(y_p, residuals , color = 'red')
plt.plot([0,200],[0,0])
plt.show()
# Out:
# y hat =  -164.25045534132457 + 1.327842233015826 x
# 0.579916569987053

# %%
## we can drop the Sports and Season column as they all have the same value and doesnt affect our analysis
df.Sport.unique(),df.Season.unique()
# Out:
# (array(['Athletics'], dtype=object), array(['Summer'], dtype=object))

# %%
df.drop(['Sport','Season'],axis = 1,inplace = True)

# %%
df
# Out:
#           ID                                       Name Sex   Age  Height  \
# 0         67    Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0
# 1        411                             Gezahgne Abera   M  22.0   166.0
# 2        428                          Elvan Abeylegesse   F  25.0   159.0
# 3        846       Valerie Kasanita Adams-Vili (-Price)   F  23.0   193.0
# 4        846       Valerie Kasanita Adams-Vili (-Price)   F  27.0   193.0
# ...      ...                                        ...  ..   ...     ...
# 1108  135095                            Szymon Zikowski   M  24.0   192.0
# 1109  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  35.0   183.0
# 1110  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  39.0   183.0
# 1111  135563                  Olesya Nikolayevna Zykina   F  19.0   171.0
# 1112  135563                  Olesya Nikolayevna Zykina   F  23.0   171.0
#
#       Weight         Team  NOC        Games  Year     City  \
# ...

# %%
df1 = df[df['Medal']=='Gold']
df2 = df[df['Medal']=='Silver']
df3 = df[df['Medal']=='Bronze']

# %%
df.City.unique()
# Out:
# array(['Beijing', 'Sydney', 'London', 'Rio de Janeiro', 'Atlanta',
#        'Athina'], dtype=object)

# %%
df.Team.unique()
# Out:
# array(['Russia', 'Ethiopia', 'Turkey', 'New Zealand', 'United States',
#        'Nigeria', 'Canada', 'Saudi Arabia', 'Lithuania',
#        'Trinidad and Tobago', 'Botswana', 'Ukraine', 'Japan', 'France',
#        'Great Britain', 'Jamaica', 'Belarus', 'Czech Republic', 'Bahamas',
#        'Greece', 'Italy', 'Cuba', 'Guatemala', 'Qatar', 'Romania',
#        'Spain', 'Morocco', 'Sweden', 'Australia', 'Kenya', 'Belgium',
#        'Brazil', 'Germany', 'Slovenia', 'China', 'Puerto Rico',
#        'Bulgaria', 'Portugal', 'Latvia', 'Iceland', 'Namibia', 'Tunisia',
#        'Mexico', 'Austria', 'Iran', 'Algeria', 'Finland', 'South Africa',
#        'Colombia', 'Sudan', 'Bahrain', 'Grenada', 'Sri Lanka', 'Uganda',
#        'Estonia', 'Kazakhstan', 'Denmark', 'Hungary', 'Croatia', 'Poland',
#        'South Korea', 'Zambia', 'Cameroon', 'Mozambique', 'Tajikistan',
#        'Burundi', 'Ireland', 'Ecuador', 'Norway', 'Venezuela', 'Panama',
# ...

# %%
y_2008_bro = df[df['Year']==2008][df[df['Year']==2008]['Medal']=='Bronze']
y_2008_bro = pd.concat([y_2008_bro,pd.get_dummies(y_2008_bro.Medal)],axis = 1).groupby(['Team'],as_index=False).sum()
plt.barh(y_2008_bro.Team,y_2008_bro.Bronze)
plt.title("No of Medals won by each country in 2008")
plt.xlabel('Bronze MEDALS in 2008')
plt.ylabel('Countries')
plt.show()

# %%
groupedGender = pd.concat([df,pd.get_dummies(df.Sex)],axis=1).groupby(['Team','ID'],as_index = False).sum()
groupedGender
# Out:
#               Team      ID   Age  Height  Weight  Year  F  M
# 0          Algeria   45314  23.0   189.0    70.0  2000  0  1
# 1          Algeria   73857  80.0   510.0   201.0  6044  0  3
# 2          Algeria   78805  29.0   162.0    54.0  2000  1  0
# 3          Algeria   81861  26.0   175.0    60.0  1996  0  1
# 4          Algeria  104345  23.0   187.0    70.0  2000  0  1
# ..             ...     ...   ...     ...     ...   ... .. ..
# 806  United States  130862  28.0   170.0    65.0  1996  1  0
# 807  United States  130969  28.0   178.0    62.0  2008  1  0
# 808  United States  131145  23.0   178.0    79.0  2008  0  1
# 809      Venezuela  102089  20.0   192.0    72.0  2016  1  0
# 810         Zambia   76386  27.0   183.0    81.0  1996  0  1
#
# [811 rows x 8 columns]

# %%
groupedGender = groupedGender.groupby('Team',as_index=False).sum()
groupedGender
# Out:
#              Team       ID     Age   Height   Weight    Year   F    M
# 0         Algeria   488534   203.0   1408.0    525.0   16040   1    7
# 1       Australia  1079878   500.0   3567.5   1365.0   40116   7   13
# 2         Austria   101888    59.0    342.0    120.0    3996   2    0
# 3         Bahamas  1515324   938.0   6167.0   2461.0   70188  14   21
# 4         Bahrain   168378    78.0    487.0    161.0    6044   3    0
# ..            ...      ...     ...      ...      ...     ...  ..  ...
# 73         Uganda   117722    51.0    352.0    129.0    4008   0    2
# 74        Ukraine  1525926   582.0   3742.0   1519.0   42124  15    6
# 75  United States  9407300  5868.0  40060.0  16376.0  451492  98  127
# 76      Venezuela   102089    20.0    192.0     72.0    2016   1    0
# 77         Zambia    76386    27.0    183.0     81.0    1996   0    1
#
# [78 rows x 8 columns]

# %%
plt.bar(groupedGender.Team,groupedGender.M)
plt.bar(groupedGender.Team,groupedGender.F)
plt.legend(['Male','Female'])
plt.xlabel("Team")
plt.ylabel("PARTICIPANTS")
plt.xticks(rotation =-90)
plt.title("Male and  Female Participants over the years")
# Out:
# Text(0.5, 1.0, 'Male and  Female Participants over the years')

# %%
Russia = df[df['Team']=='Russia']
Russia = pd.concat([Russia,pd.get_dummies(Russia.Medal)],axis = 1).groupby(['Year'],as_index = False).sum()
Russia
width = 0.80
plt.bar(Russia.Year - 0.8 ,Russia.Bronze,width,color = 'blue')
plt.bar(Russia.Year + 0 , Russia.Silver,width,color = 'Red')
plt.bar(Russia.Year +0.8, Russia.Gold,width,color = 'orange')
plt.legend(['Bronze','Silver','Gold'])
plt.title('Medals Won by Russia')
plt.xlabel('Year')
plt.ylabel(' Number of Medals')
plt.plot()
# Out:
# []

# %%
dfage = df.groupby(['Year','ID'],as_index=False).mean()
dfage
dfage = dfage[np.isfinite(dfage['Age'])]
dfage = dfage.groupby('Year',as_index= False).mean()
plt.plot(dfage.Year,dfage.Age,color='Red')
plt.xticks(range(1996,2018,4))
plt.xlabel('Year')
plt.ylabel('Age')
plt.title('Age Distribution  over the Years')
plt.show()
